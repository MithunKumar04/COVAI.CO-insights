# %%
import pandas as pd

# %%
df=pd.read_csv("Daily_Public_Transport_Passenger_Journeys_by_Service_Type_20250526.csv")

# %%
df
# Out:
#             Date  Local Route  Light Rail  Peak Service  Rapid Route  School  \
# 0     30/08/2024        16436       10705           225        19026    3925
# 1     15/09/2023        15499       10671           267        18421    4519
# 2     28/12/2021         1756        2352             0         3775       0
# 3     11/01/2023        10536        8347           223        14072       0
# 4     11/09/2021          820         612             0         1283       0
# ...          ...          ...         ...           ...          ...     ...
# 1913  19/01/2023        11337        8671           262        14881       0
# 1914  16/08/2023        16791       11800           387        20936    4684
# 1915  10/01/2022         5732        3548            73         6644       0
# 1916  04/05/2020         3717        1952            70         4411     131
# 1917  26/07/2023        16680       11726           347        20438    4738
#
#       Other
# 0      59.0
# 1      61.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
df["Date"]=pd.to_datetime(df["Date"])
# Out:
# C:\Users\mithu\AppData\Local\Temp\ipykernel_20948\1380596044.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Date"]=pd.to_datetime(df["Date"])

# %%
df=df.sort_values(by="Date",ascending=False)

# %%
df.head(20)
# Out:
#            Date  Local Route  Light Rail  Peak Service  Rapid Route  School  \
# 160  2024-09-29            1           0             0            3       0
# 1652 2024-09-28            1           0             0            4       0
# 1731 2024-09-27            6           0             0           13       0
# 1330 2024-09-26            9           0             0            0       2
# 1662 2024-09-25           21           0             1           10       8
# 1689 2024-09-24           36          78             0           21       3
# 1800 2024-09-23           56        1938             0           67      10
# 1810 2024-09-22           21         577             0           49       0
# 1387 2024-09-21           28         832             0           64       0
# 1613 2024-09-20          485        2537             0          440      37
# 973  2024-09-19        16129       10469           288        19650    4557
# ...

# %%
import numpy as np

# %%
result=np.where(df["School"]==0)

# %%
result
# Out:
# (array([   0,    1,    2,    7,    8,   14,   15,   21,   22,   28,   29,
#           35,   36,   42,   43,   49,   50,   56,   63,   64,   70,   71,
#           72,   73,   74,   75,   76,   77,   78,   79,   80,   81,   82,
#           83,   84,   85,   91,   92,   98,  105,  106,  111,  112,  113,
#          119,  120,  125,  126,  127,  133,  134,  140,  141,  147,  148,
#          154,  155,  156,  157,  158,  159,  160,  161,  162,  163,  164,
#          165,  166,  167,  168,  169,  175,  176,  181,  182,  183,  184,
#          189,  190,  196,  202,  203,  204,  210,  211,  217,  218,  224,
#          225,  231,  232,  238,  239,  245,  246,  247,  248,  249,  250,
#          251,  252,  253,  254,  255,  256,  257,  258,  259,  260,  261,
#          262,  263,  264,  265,  266,  267,  268,  269,  270,  271,  272,
#          273,  274,  275,  276,  277,  278,  279,  280,  281,  282,  283,
#          284,  285,  286,  287,  288,  294,  295,  301,  302,  308,  309,
# ...

# %%
len(result[0])
# Out:
# 901

# %%
plt.plot(df["Date"],df["Peak Service"])

# %%
df=df.sort_values(by="Peak Service",ascending=False)

# %%
df
# Out:
#            Date  Local Route  Light Rail  Peak Service  Rapid Route  School  \
# 798  2023-11-10        16397       11100          1029        19102    4550
# 155  2020-02-11        20335       12064           529        26842    7255
# 350  2020-02-25        21059       13128           529        28340    6634
# 119  2020-02-24        20110       12211           516        26749    6622
# 1214 2020-03-03        19623       12961           514        27706    2551
# ...         ...          ...         ...           ...          ...     ...
# 163  2022-01-26         1716        2424             0         3957       0
# 1856 2022-01-23         1616        2475             0         3771       0
# 995  2022-01-22         2402        3283             0         4831       0
# 1103 2022-01-16         1602        2180             0         3427       0
# 464  2022-02-13         2005        2887             0         4341       0
#
#       Other    Leave
# 798    81.0  Working
# ...
